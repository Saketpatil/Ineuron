# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12248\2410042436.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('C:/Users/DELL/Desktop/Instagram/Instagram data.csv', encoding='latin-1')
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# 2  Learn how to train a machine learning model an...
# 3  Heres how you can write a Python program to d...
# 4  Plotting annotations while visualizing your da...
#
#                                             Hashtags
# 0  #finance #money #business #investing #investme...
# 1  #healthcare #health #covid #data #datascience ...
# 2  #data #datascience #dataanalysis #dataanalytic...
# 3  #python #pythonprogramming #pythonprojects #py...
# 4  #datavisualization #datascience #data #dataana...

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df)

# %%
num_clusters = 2

# %%
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
cluster_labels = kmeans.labels_

# %%
print("Social Media Data Clustering Results:")
print("--------------------------------------")
print("The K-Means clustering algorithm has been applied to categorize users based on their social media activities.")
print("")
# Out:
# Social Media Data Clustering Results:
# --------------------------------------
# The K-Means clustering algorithm has been applied to categorize users based on their social media activities.

# %%
for i, label in enumerate(cluster_labels):
    print(f"Social media data point {i + 1} belongs to cluster {label + 1}.")
print("")
# Out:
# Social media data point 1 belongs to cluster 1.
# Social media data point 2 belongs to cluster 1.
# Social media data point 3 belongs to cluster 1.
# Social media data point 4 belongs to cluster 1.
# Social media data point 5 belongs to cluster 1.
# Social media data point 6 belongs to cluster 1.
# Social media data point 7 belongs to cluster 1.
# Social media data point 8 belongs to cluster 1.
# Social media data point 9 belongs to cluster 1.
# Social media data point 10 belongs to cluster 2.
# Social media data point 11 belongs to cluster 1.
# Social media data point 12 belongs to cluster 1.
# Social media data point 13 belongs to cluster 1.

# %%
print("Elaboration:")
print("-------------")
print("In the context of the provided problem statement, the clustering process aims to categorize users into distinct groups based on their activities and interactions on social media platforms.")
print("By applying the K-Means algorithm, which is a popular technique in data mining, users are partitioned into clusters with similar characteristics.")
print("")
# Out:
# Elaboration:
# -------------
# In the context of the provided problem statement, the clustering process aims to categorize users into distinct groups based on their activities and interactions on social media platforms.
# By applying the K-Means algorithm, which is a popular technique in data mining, users are partitioned into clusters with similar characteristics.

# %%
print("This clustering process enables the identification of user communities or groups who engage with specific types of content, such as posts related to the film industry or political discussions.")
print("The TF-IDF vectorization technique is employed to transform the text data from social media posts into numerical features, allowing for the application of the K-Means algorithm.")
print("")
# Out:
# This clustering process enables the identification of user communities or groups who engage with specific types of content, such as posts related to the film industry or political discussions.
# The TF-IDF vectorization technique is employed to transform the text data from social media posts into numerical features, allowing for the application of the K-Means algorithm.

# %%
print("The number of clusters is pre-defined based on the desired granularity of user categorization.")
print(f"In this case, {num_clusters} clusters have been specified.")
print("")
# Out:
# The number of clusters is pre-defined based on the desired granularity of user categorization.
# In this case, 2 clusters have been specified.

# %%
print("Each social media data point is assigned a cluster label, indicating the category to which the user belongs.")
print("These cluster labels can be further analyzed to gain insights into user behavior and preferences, aiding in user classification and community identification.")
# Out:
# Each social media data point is assigned a cluster label, indicating the category to which the user belongs.
# These cluster labels can be further analyzed to gain insights into user behavior and preferences, aiding in user classification and community identification.
